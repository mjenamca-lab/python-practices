# %%
a=10
b=20
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
a
b
# Out:
# 20

# %%
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(10,20)
print('python')
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1=20
num2=30
add=num1+num2
print(add)
# Out:
# 50

# %%
num1=20
num2=30
add=num1+num2
print('the addition of ',num1,'and',num2,'is=',add)
# Out:
# the addition of  20 and 30 is= 50

# %%
name='python'
age=20
city='hyd'
print('Hello my name is' ,name, 'and i am', age, 'years old from',city)
# Out:
# Hello my name is python and i am 20 years old from hyd

# %%
num1=20
num2=30
add=num1+num2
print('the addition of',num1 ,'and ',num2, 'is=',add)
# Out:
# the addition of 20 and  30 is= 50

# %%
name = 'Python'
age = 20
city = 'hyd'

print('hello my name is {}, and i am {} years old from {}'.format(name, age, city))
# Out:
# hello my name is Python, and i am 20 years old from hyd

# %%
num1=100 
num2=25 
num3=333 
num1=20 
num2=30 
avg=(num1+num2+num3)/3 # or we can use avg=round(num1+num2+num3)/3,2) 
avg1=round((num1+num2+num3)/3,2) 
# The avrage of num1,num2,num3 is = avg 
print('The avrage of {}, {}, and {} is= {} or {}'.format(num1,num2,num3, 
avg,avg1)) # here we can use round(avg,2) also
# Out:
# The avrage of 20, 30, and 333 is= 127.66666666666667 or 127.67

# %%
#Evaluate any expressions inside {} and insert their values into the string.”

num1=20
num2=30
add=num1+num2
print(F'The addition of {num1} and {num2} is={add}')
# Out:
# The addition of 20 and 30 is=50

# %%
name='python'
age=20
city='hyd'
print(F'hello my name is {name} and i am ten years old from {city}')
# Out:
# hello my name is python and i am ten years old from hyd

# %%
num1=100 
num2=25 
num3=333 
avg=round((num1+num2+num3)/3,2)
print(F'The avrage of {num1},{num2} and {num3} is = avg')
# Out:
# The avrage of 100,25 and 333 is = avg

# %% [markdown]
# num1=10
# num2=20
# add = num1+ num2
# print('The addition of',num1,'and',num2,'is=',add)
# print('The addition of {} and {} is= {}'.format(num1,num2,add))
# print(f'The addition of {num1} and {num2} is= {add}')
#
# ---

# %% [markdown]
# ##End statement

# %%
print('hello') # 1st statement 
print('good moorning') # 2nd statement) 
# i want print like:- hellow good morning
# Out:
# hello
# good moorning

# %%
print('hello', end=' ') # 1st statement 
print('world good day') # 2nd statement
# Out:
# hello world good day

# %% [markdown]
# ##Separator
# here one print statement only we use
#
# insisde one print statement we have multiple values
#
# we want to seperate these multiple values with anything

# %%
print('hello','hai','how are you',sep='--->')
# Out:
# hello--->hai--->how are you

# %%
print('hello','hai','how are you',sep='&')
# Out:
# hello&hai&how are you

# %%
print('hello','hai','how are you',sep='@')
# Out:
# hello@hai@how are you

# %%
print(3,'.') # . is far from 3 so here we will use sep method
# Out:
# 3 .

# %%
print(3,'.',sep='')
# Out:
# 3.

# %%
print(1,2,end=' ') 
print(3,'.',sep='') 
# will print 1 2 3.
# Out:
# 1 2 3.
