# %%
#Syntax
#variable_name=value
#int variable
age=25
print(age)
# Out:
# 25

# %%
#String Variable
Name="madhu"
print(Name)
# Out:
# madhu

# %%
#Float Variable
price=12.50
print(price)
# Out:
# 12.5

# %%
#Bloolean Variable
Is_active=True
print(Is_active)
# Out:
# True

# %%
#Storing and printing a value
x=10
print(x)
# Out:
# 10

# %%
#Usimg Variable in Expression
a=5
b=6
result=a+b
print(result)
# Out:
# 11

# %%
#changing the value of a variable
score=50
print(score)
# Out:
# 50

# %%
score=100
print(score)
# Out:
# 100

# %%
#concatenating string
Firstname="Madhu"
Last_Name="Jena"
full_name=Firstname+" "+Last_Name
print(full_name)
# Out:
# Madhu Jena

# %%
#using Variaable in  a calculation
length=10
width=20
area= length * width
print(area)
# Out:
# 200
